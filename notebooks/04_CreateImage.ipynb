# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.
#
# # Create Image
# In this notebook, we show the following steps for deploying a web service using AzureML:
# - Create an image
# - Test image locally

# %%
from azure_utils.machine_learning.realtime.image import get_or_create_image, lightgbm_test_image_locally, get_model
from azure_utils.machine_learning.realtime.image import create_lightgbm_image_config

#from notebooks import directory
directory="/home/riversand/notebooks/az-ml-realtime-score/notebooks"
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
from azure_utils.machine_learning.realtime.image import ContainerImage

# %%
??get_or_create_image

# %% [markdown]
# AML will use the following information to create an image, provision a cluster and deploy a service. Replace the
# values in the following cell with your information.

# %% [markdown]
# ## Create an image
# We will now modify the `score.py` created in the previous notebook for the `init()` function to use the model we
# registered to the workspace earlier.

# %%
# %%writefile score.py

import sys
import json
import logging
import timeit as t
from azureml.core.model import Model
from azureml.contrib.services.aml_request import rawhttp
from azureml.contrib.services.aml_response import AMLResponse
from azure_utils.machine_learning.duplicate_model import DuplicateModel

sys.path.append('./scripts/')


def init():
    logger = logging.getLogger("scoring_script")
    global model
    model_name = 'question_match_model'
    model_path = Model.get_model_path(model_name)
    questions_path = './notebooks/data_folder/questions.tsv'
    start = t.default_timer()
    model = DuplicateModel(model_path, questions_path)
    end = t.default_timer()
    load_time_msg = "Model loading time: {0} ms".format(
        round((end - start) * 1000, 2))
    logger.info(load_time_msg)


@rawhttp
def run(request):
    """
    Function runs on each request
    """
    body = request.data
    if request.method == 'POST':
        logger = logging.getLogger("scoring_script")
        json_load_text = json.loads(body)
        text_to_score = json_load_text['input']
        start = t.default_timer()
        resp = model.score(text_to_score)
        end = t.default_timer()
        logger.info("Prediction took {0} ms".format(
            round((end - start) * 1000, 2)))
        return json.dumps(resp)
    if request.method == 'GET':
        resp_body = {
            "azEnvironment": "Azure",
            "location": "westus2",
            "osType": "Ubuntu 16.04",
            "resourceGroupName": "",
            "resourceId": "",
            "sku": "",
            "subscriptionId": "",
            "uniqueId": "PythonMLRST",
            "vmSize": "",
            "zone": "",
            "isServer": False,
            "version": ""
        }
        return resp_body
    return AMLResponse("bad request", 500)
# Out:
# Overwriting score.py

# %% [markdown]
# Let's specify the conda and pip dependencies for the image.

# %%
??get_model

# %%
# !pwd
# Out:
# /home/riversand/notebooks/az-ml-realtime-score/notebooks

# %%
#dependencies = ["./notebooks/data_folder/questions.tsv"]
dependencies = ["/home/riversand/notebooks/az-ml-realtime-score/data_folder/questions.tsv"]
#models = [get_model(model_name='question_match_model')]
#models=[Model(ws, name='question_match_model')]
model_name = 'question_match_model'
from azureml.core.authentication import MsiAuthentication
from azureml.core import Workspace
from azureml.core.model import Model
from azureml.core.image import Image
msi_auth = MsiAuthentication()
ws = Workspace(subscription_id="109e56d8-d599-4905-ab89-be3f6c7e1662",
               resource_group="trial2",
               workspace_name="experiment2ml",
               auth=msi_auth)
models = [Model(ws, name='question_match_model')]
# image = Image(models=models, dependencies=dependencies)

# %%
dependencies = "./data_folder/questions.tsv"

# %%
dependencies = "/anaconda/envs/az-ml-realtime-score/bin/python"

# %%
??create_lightgbm_image_config

# %%
image_config = create_lightgbm_image_config()

# %%
image = ContainerImage.create(name="imageml5", models=models, image_config=image_config, workspace=ws)
image.wait_for_creation(show_output=True)
# Out:
# /anaconda/envs/az-ml-realtime-score/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Image class has been deprecated and will be removed in a future release. Please migrate to using Environments. https://docs.microsoft.com/en-us/azure/machine-learning/how-to-use-environments
#   """Entry point for launching an IPython kernel.
# Creating image
# Running...............................................................
# Succeeded
# Image creation operation finished for image imageml5:2, operation "Succeeded"

# %%
print(image.name)
print(image.version)
print(image.image_build_log_uri)
# Out:
# imageml5
# 2
# https://experiment2ml4711566172.blob.core.windows.net/azureml/ImageLogs/b4c3415d-5d97-48cd-9af0-6c8c4cdbce34/build.log?sv=2018-03-28&sr=b&sig=uNquM6YEIigNj4FIgtT3Ooy9BXLEX64XXjcbDNPmhFg%3D&st=2020-04-16T11%3A32%3A53Z&se=2020-05-16T11%3A37%3A53Z&sp=rl

# %%
print(image.name)
print(image.version)
print(image.image_build_log_uri)
# Out:
# imageml
# 1
# https://experiment2ml4711566172.blob.core.windows.net/azureml/ImageLogs/f0697704-8edb-4c77-a359-9559211a1f37/build.log?sv=2018-03-28&sr=b&sig=nvy1%2B7b8D4i4CQfv3lgqFs%2FKfIU69HX7pM7k1sVyl98%3D&st=2020-04-15T12%3A41%3A43Z&se=2020-05-15T12%3A46%3A43Z&sp=rl

# %%
# def get_or_create_image(configuration_file: str = project_configuration_file, show_output: bool = True,
#                         models: list = None, dependencies=None) -> ContainerImage:
#     """
#     Get or Create new Docker Image from Machine Learning Workspace

#     :param configuration_file: path to project configuration file. default: project.yml
#     :param show_output: toggle on/off standard output. default: `True`
#     :param models Name of Model to package with Image from Machine Learning Workspace
#     :param dependencies: List of files to include in image
#     :return: New or Existing Docker Image for deployment to Kubernetes Compute
#     """
#     project_configuration = ProjectConfiguration(configuration_file)
#     assert project_configuration.has_settings("image_name")

#     image_name = project_configuration.get_value("image_name")
#     if not models:
#         models = []

#     workspace = get_or_create_workspace_from_project(project_configuration, show_output=show_output)

#     workspace_images = workspace.images
#     if image_name in workspace_images and workspace_images[image_name].creation_state != "Failed":
#         return workspace_images[image_name]

#     image_config = create_lightgbm_image_config(dependencies=dependencies)

#     image_create_start = time.time()

#     image = ContainerImage.create(name=image_name, models=models, image_config=image_config, workspace=workspace)
#     image.wait_for_creation(show_output=show_output)
#     assert image.creation_state != "Failed"
#     if show_output:
#         deployment_time_secs = str(time.time() - image_create_start)
#         print("Deployed Image with name " + image_name + ". Took " + deployment_time_secs + " seconds.")
#         print(image.name)
#         print(image.version)
#         print(image.image_build_log_uri)
#     return image

# %%
??Image

# %%
1

# %% [markdown]
# ## Test image locally

# %% [markdown]
# Now, let's use one of the duplicate questions to test our image.

# %%
# !sudo usermod -aG docker riversand

# %%
# !newgrp docker
# Out:
# riversand@experiment2:~/notebooks/az-ml-realtime-score/notebooks$ ^C
#
# riversand@experiment2:~/notebooks/az-ml-realtime-score/notebooks$

# %%
1
# Out:
# 1

# %%
directory="/home/riversand/notebooks/az-ml-realtime-score/notebooks"
lightgbm_test_image_locally(image, directory)
# Out:
# Logging into Docker registry experiment2m230df60f.azurecr.io/imageml5:2
# Pulling image from ACR (this may take a few minutes depending on image size)...
#
# 2: Pulling from imageml5
# 0a01a72a686c: Pulling fs layer
# cc899a5544da: Pulling fs layer
# 19197c550755: Pulling fs layer
# 716d454e56b6: Pulling fs layer
# 531e1a9d7834: Pulling fs layer
# 923dd6f29cbd: Pulling fs layer
# ccb5807abf9d: Pulling fs layer
# c9c64a9f39c1: Pulling fs layer
# 267fe7ac51f6: Pulling fs layer
# e96ee6a62ed8: Pulling fs layer
# 3d18abd3e1b9: Pulling fs layer
# 66c12c72445e: Pulling fs layer
# 356401da5ff8: Pulling fs layer
# 85548c7822bb: Pulling fs layer
# bada6c1a900f: Pulling fs layer
# 9f918645f712: Pulling fs layer
# 49ade0f1b3a4: Pulling fs layer
# be401f42d196: Pulling fs layer
# 83bd53787cff: Pulling fs layer
# 5fc72daf3ed2: Pulling fs layer
# 390c7a8bf489: Pulling fs layer
# c35b7e1c64ff: Pulling fs layer
# 88ee4051df22: Pulling fs layer
# 63065ac16993: Pulling fs layer
# c887e10d5d48: Pulling fs layer
# 1299f0b92443: Pulling fs layer
# 77a275a99b09: Pulling fs layer
# b3450284d9da: Pulling fs layer
# b7fc5fe3deed: Pulling fs layer
# b4e4f799245b: Pulling fs layer
# 0b9d5e19aa4f: Pulling fs layer
# 2f79ce1c1110: Pulling fs layer
# dd71c0e85fa6: Pulling fs layer
# a2213101b860: Pulling fs layer
# cb4a193236c6: Pulling fs layer
# 55dc61beffe2: Pulling fs layer
# 716d454e56b6: Waiting
# 531e1a9d7834: Waiting
# 923dd6f29cbd: Waiting
# ccb5807abf9d: Waiting
# c9c64a9f39c1: Waiting
# 267fe7ac51f6: Waiting
# e96ee6a62ed8: Waiting
# 3d18abd3e1b9: Waiting
# 66c12c72445e: Waiting
# 356401da5ff8: Waiting
# 85548c7822bb: Waiting
# bada6c1a900f: Waiting
# 9f918645f712: Waiting
# 49ade0f1b3a4: Waiting
# be401f42d196: Waiting
# 83bd53787cff: Waiting
# 5fc72daf3ed2: Waiting
# 390c7a8bf489: Waiting
# c35b7e1c64ff: Waiting
# 88ee4051df22: Waiting
# 63065ac16993: Waiting
# c887e10d5d48: Waiting
# 1299f0b92443: Waiting
# 77a275a99b09: Waiting
# b3450284d9da: Waiting
# b7fc5fe3deed: Waiting
# b4e4f799245b: Waiting
# 0b9d5e19aa4f: Waiting
# 2f79ce1c1110: Waiting
# dd71c0e85fa6: Waiting
# a2213101b860: Waiting
# cb4a193236c6: Waiting
# 55dc61beffe2: Waiting
# 0a01a72a686c: Downloading
# 19197c550755: Downloading
# 19197c550755: Download complete
# 0a01a72a686c: Downloading
# cc899a5544da: Downloading
# cc899a5544da: Verifying Checksum
# cc899a5544da: Download complete
# 716d454e56b6: Downloading
# 716d454e56b6: Verifying Checksum
# 716d454e56b6: Download complete
# 0a01a72a686c: Downloading
# 531e1a9d7834: Downloading
# 0a01a72a686c: Downloading
# 531e1a9d7834: Downloading
# 923dd6f29cbd: Downloading
# 923dd6f29cbd: Verifying Checksum
# 923dd6f29cbd: Download complete
# 0a01a72a686c: Downloading
# 531e1a9d7834: Downloading
# 0a01a72a686c: Downloading
# ccb5807abf9d: Downloading
# 531e1a9d7834: Downloading
# 0a01a72a686c: Downloading
# ccb5807abf9d: Downloading
# 531e1a9d7834: Downloading
# ccb5807abf9d: Verifying Checksum
# ccb5807abf9d: Download complete
# 0a01a72a686c: Downloading
# 531e1a9d7834: Downloading
# 0a01a72a686c: Downloading
# 531e1a9d7834: Downloading
# c9c64a9f39c1: Downloading
# 0a01a72a686c: Downloading
# 531e1a9d7834: Downloading
# c9c64a9f39c1: Downloading
# 531e1a9d7834: Verifying Checksum
# 531e1a9d7834: Download complete
# 0a01a72a686c: Downloading
# c9c64a9f39c1: Downloading
# 0a01a72a686c: Downloading
# c9c64a9f39c1: Downloading
# 0a01a72a686c: Downloading
# 267fe7ac51f6: Downloading
# 267fe7ac51f6: Verifying Checksum
# 267fe7ac51f6: Download complete
# c9c64a9f39c1: Downloading
# 0a01a72a686c: Downloading
# c9c64a9f39c1: Downloading
# 0a01a72a686c: Downloading
# c9c64a9f39c1: Downloading
# e96ee6a62ed8: Downloading
# e96ee6a62ed8: Verifying Checksum
# e96ee6a62ed8: Download complete
# 0a01a72a686c: Downloading
# c9c64a9f39c1: Downloading
# 0a01a72a686c: Downloading
# c9c64a9f39c1: Downloading
# 3d18abd3e1b9: Downloading
# 0a01a72a686c: Downloading
# c9c64a9f39c1: Downloading
# 3d18abd3e1b9: Downloading
# 0a01a72a686c: Downloading
# c9c64a9f39c1: Downloading
# 3d18abd3e1b9: Downloading
# c9c64a9f39c1: Verifying Checksum
# c9c64a9f39c1: Download complete
# 0a01a72a686c: Downloading
# 3d18abd3e1b9: Downloading
# 0a01a72a686c: Downloading
# 66c12c72445e: Downloading
# 66c12c72445e: Download complete
# 3d18abd3e1b9: Downloading
# 356401da5ff8: Downloading
# 356401da5ff8: Download complete
# 0a01a72a686c: Downloading
# 3d18abd3e1b9: Downloading
# 0a01a72a686c: Downloading
# 85548c7822bb: Downloading
# 85548c7822bb: Verifying Checksum
# 85548c7822bb: Download complete
# 3d18abd3e1b9: Downloading
# 0a01a72a686c: Downloading
# 3d18abd3e1b9: Downloading
# bada6c1a900f: Downloading
# bada6c1a900f: Downloading
# bada6c1a900f: Verifying Checksum
# bada6c1a900f: Download complete
# 0a01a72a686c: Downloading
# 3d18abd3e1b9: Downloading
# 0a01a72a686c: Downloading
# 9f918645f712: Downloading
# 9f918645f712: Verifying Checksum
# 9f918645f712: Download complete
# 0a01a72a686c: Verifying Checksum
# 0a01a72a686c: Download complete
# 3d18abd3e1b9: Downloading
# be401f42d196: Downloading
# be401f42d196: Verifying Checksum
# be401f42d196: Download complete
# 3d18abd3e1b9: Downloading
# 49ade0f1b3a4: Downloading
# 49ade0f1b3a4: Verifying Checksum
# 49ade0f1b3a4: Download complete
# 83bd53787cff: Downloading
# 83bd53787cff: Verifying Checksum
# 83bd53787cff: Download complete
# 0a01a72a686c: Extracting
# 3d18abd3e1b9: Downloading
# 0a01a72a686c: Extracting
# 390c7a8bf489: Downloading
# 390c7a8bf489: Verifying Checksum
# 390c7a8bf489: Download complete
# 5fc72daf3ed2: Downloading
# 5fc72daf3ed2: Verifying Checksum
# 5fc72daf3ed2: Download complete
# 3d18abd3e1b9: Downloading
# 0a01a72a686c: Extracting
# 3d18abd3e1b9: Verifying Checksum
# 3d18abd3e1b9: Download complete
# c35b7e1c64ff: Downloading
# c35b7e1c64ff: Downloading
# c35b7e1c64ff: Verifying Checksum
# c35b7e1c64ff: Download complete
# 88ee4051df22: Downloading
# 88ee4051df22: Verifying Checksum
# 88ee4051df22: Download complete
# 63065ac16993: Downloading
# 63065ac16993: Verifying Checksum
# 63065ac16993: Download complete
# 0a01a72a686c: Extracting
# c887e10d5d48: Downloading
# c887e10d5d48: Verifying Checksum
# c887e10d5d48: Download complete
# 1299f0b92443: Downloading
# 1299f0b92443: Verifying Checksum
# 1299f0b92443: Download complete
# 0a01a72a686c: Extracting
# b3450284d9da: Downloading
# b3450284d9da: Verifying Checksum
# b3450284d9da: Download complete
# b7fc5fe3deed: Downloading
# b7fc5fe3deed: Verifying Checksum
# b7fc5fe3deed: Download complete
# 0b9d5e19aa4f: Downloading
# 0b9d5e19aa4f: Verifying Checksum
# 0b9d5e19aa4f: Download complete
# 0a01a72a686c: Extracting
# b4e4f799245b: Downloading
# b4e4f799245b: Verifying Checksum
# b4e4f799245b: Download complete
# 0a01a72a686c: Extracting
# 2f79ce1c1110: Downloading
# 2f79ce1c1110: Verifying Checksum
# 2f79ce1c1110: Download complete
# 0a01a72a686c: Extracting
# a2213101b860: Downloading
# a2213101b860: Verifying Checksum
# a2213101b860: Download complete
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# 77a275a99b09: Downloading
# 77a275a99b09: Verifying Checksum
# 77a275a99b09: Download complete
# cb4a193236c6: Downloading
# dd71c0e85fa6: Downloading
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# dd71c0e85fa6: Downloading
# 0a01a72a686c: Extracting
# 55dc61beffe2: Downloading
# cb4a193236c6: Downloading
# 55dc61beffe2: Downloading
# 55dc61beffe2: Verifying Checksum
# 55dc61beffe2: Download complete
# 0a01a72a686c: Extracting
# dd71c0e85fa6: Downloading
# cb4a193236c6: Downloading
# 0a01a72a686c: Extracting
# dd71c0e85fa6: Downloading
# cb4a193236c6: Downloading
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# dd71c0e85fa6: Downloading
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# dd71c0e85fa6: Downloading
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# cb4a193236c6: Downloading
# dd71c0e85fa6: Downloading
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# dd71c0e85fa6: Downloading
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# 0a01a72a686c: Extracting
# dd71c0e85fa6: Downloading
# cb4a193236c6: Downloading
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# dd71c0e85fa6: Downloading
# cb4a193236c6: Downloading
# 0a01a72a686c: Extracting
# dd71c0e85fa6: Downloading
# 0a01a72a686c: Extracting
# cb4a193236c6: Downloading
# cb4a193236c6: Verifying Checksum
# cb4a193236c6: Download complete
# 0a01a72a686c: Extracting
# dd71c0e85fa6: Downloading
# dd71c0e85fa6: Downloading
# dd71c0e85fa6: Downloading
# 0a01a72a686c: Pull complete
# cc899a5544da: Extracting
# cc899a5544da: Extracting
# dd71c0e85fa6: Downloading
# cc899a5544da: Pull complete
# 19197c550755: Extracting
# 19197c550755: Extracting
# dd71c0e85fa6: Downloading
# 19197c550755: Pull complete
# 716d454e56b6: Extracting
# 716d454e56b6: Extracting
# dd71c0e85fa6: Downloading
# 716d454e56b6: Pull complete
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# 531e1a9d7834: Extracting
# dd71c0e85fa6: Downloading
# dd71c0e85fa6: Downloading
# dd71c0e85fa6: Downloading
# dd71c0e85fa6: Verifying Checksum
# dd71c0e85fa6: Download complete
# 531e1a9d7834: Extracting
# 531e1a9d7834: Extracting
# 531e1a9d7834: Pull complete
# 923dd6f29cbd: Extracting
# 923dd6f29cbd: Extracting
# 923dd6f29cbd: Pull complete
# ccb5807abf9d: Extracting
# ccb5807abf9d: Extracting
# ccb5807abf9d: Extracting
# ccb5807abf9d: Extracting
# ccb5807abf9d: Extracting
# ccb5807abf9d: Extracting
# ccb5807abf9d: Pull complete
# c9c64a9f39c1: Extracting
# c9c64a9f39c1: Extracting
# c9c64a9f39c1: Extracting
# c9c64a9f39c1: Extracting
# c9c64a9f39c1: Extracting
# c9c64a9f39c1: Extracting
# c9c64a9f39c1: Extracting
# c9c64a9f39c1: Extracting
# c9c64a9f39c1: Extracting
# c9c64a9f39c1: Pull complete
# 267fe7ac51f6: Extracting
# 267fe7ac51f6: Extracting
# 267fe7ac51f6: Pull complete
# e96ee6a62ed8: Extracting
# e96ee6a62ed8: Extracting
# e96ee6a62ed8: Pull complete
# 3d18abd3e1b9: Extracting
# 3d18abd3e1b9: Extracting
# 3d18abd3e1b9: Extracting
# 3d18abd3e1b9: Extracting
# 3d18abd3e1b9: Extracting
# 3d18abd3e1b9: Extracting
# 3d18abd3e1b9: Extracting
# 3d18abd3e1b9: Extracting
# 3d18abd3e1b9: Extracting
# 3d18abd3e1b9: Pull complete
# 66c12c72445e: Extracting
# 66c12c72445e: Extracting
# 66c12c72445e: Pull complete
# 356401da5ff8: Extracting
# 356401da5ff8: Extracting
# 356401da5ff8: Pull complete
# 85548c7822bb: Extracting
# 85548c7822bb: Extracting
# 85548c7822bb: Pull complete
# bada6c1a900f: Extracting
# bada6c1a900f: Extracting
# bada6c1a900f: Pull complete
# 9f918645f712: Extracting
# 9f918645f712: Extracting
# 9f918645f712: Pull complete
# 49ade0f1b3a4: Extracting
# 49ade0f1b3a4: Extracting
# 49ade0f1b3a4: Pull complete
# be401f42d196: Extracting
# be401f42d196: Extracting
# be401f42d196: Pull complete
# 83bd53787cff: Extracting
# 83bd53787cff: Extracting
# 83bd53787cff: Pull complete
# 5fc72daf3ed2: Extracting
# 5fc72daf3ed2: Extracting
# 5fc72daf3ed2: Pull complete
# 390c7a8bf489: Extracting
# 390c7a8bf489: Extracting
# 390c7a8bf489: Pull complete
# c35b7e1c64ff: Extracting
# c35b7e1c64ff: Extracting
# c35b7e1c64ff: Extracting
# c35b7e1c64ff: Pull complete
# 88ee4051df22: Extracting
# 88ee4051df22: Extracting
# 88ee4051df22: Pull complete
# 63065ac16993: Extracting
# 63065ac16993: Extracting
# 63065ac16993: Pull complete
# c887e10d5d48: Extracting
# c887e10d5d48: Extracting
# c887e10d5d48: Pull complete
# 1299f0b92443: Extracting
# 1299f0b92443: Extracting
# 1299f0b92443: Pull complete
# 77a275a99b09: Extracting
# 77a275a99b09: Extracting
# 77a275a99b09: Pull complete
# b3450284d9da: Extracting
# b3450284d9da: Extracting
# b3450284d9da: Pull complete
# b7fc5fe3deed: Extracting
# b7fc5fe3deed: Extracting
# b7fc5fe3deed: Pull complete
# b4e4f799245b: Extracting
# b4e4f799245b: Extracting
# b4e4f799245b: Pull complete
# 0b9d5e19aa4f: Extracting
# 0b9d5e19aa4f: Extracting
# 0b9d5e19aa4f: Pull complete
# 2f79ce1c1110: Extracting
# 2f79ce1c1110: Extracting
# 2f79ce1c1110: Pull complete
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Extracting
# dd71c0e85fa6: Pull complete
# a2213101b860: Extracting
# a2213101b860: Extracting
# a2213101b860: Pull complete
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Extracting
# cb4a193236c6: Pull complete
# 55dc61beffe2: Extracting
# 55dc61beffe2: Extracting
# 55dc61beffe2: Extracting
# 55dc61beffe2: Extracting
# 55dc61beffe2: Pull complete
# Digest: sha256:5ad8471ef827db3143c3d1f946a9c084f68d2e2379741e435530d4d66fafd162
# Status: Downloaded newer image for experiment2m230df60f.azurecr.io/imageml5:2
# Starting Docker container...
# Docker container running.
# Checking container health...
# Making a scoring call...
# Scoring result:
# {"call": true}
# Container has been successfully cleaned up.

# %% [markdown]
# ## Conclusion
#
# We can now move on to [Deploy on Azure Kubernetes Service](05_DeployOnAKS.ipynb) notebook.
